# %%
import pandas as p

# %%
d.head
# Out:
# <bound method NDFrame.head of                                                  title  \
# 0    Data Analysis Using R (Low Priced Edition): A ...
# 1    Head First Data Analysis: A learner's guide to...
# 2    Guerrilla Data Analysis Using Microsoft Excel:...
# 3    Python for Data Analysis: Data Wrangling with ...
# 4    Excel Data Analysis For Dummies (For Dummies (...
# ..                                                 ...
# 825   Deep Learning: Engage the World Change the World
# 826  Machine Learning in Finance: From Theory to Pr...
# 827  Practical Deep Learning at Scale with MLflow: ...
# 828  Clinical Biostatistics and Epidemiology Made R...
# 829  AI and Machine Learning for Coders: A Programm...
#
#                                          author  price  \
# 0                           [ Dr Dhaval Maheta]   6.75
# 1                                           NaN  33.72
# 2            [ Oz du Soleil,  and , Bill Jelen]  32.07
# ...

# %%
d.head()
# Out:
#                                                title  \
# 0  Data Analysis Using R (Low Priced Edition): A ...
# 1  Head First Data Analysis: A learner's guide to...
# 2  Guerrilla Data Analysis Using Microsoft Excel:...
# 3  Python for Data Analysis: Data Wrangling with ...
# 4  Excel Data Analysis For Dummies (For Dummies (...
#
#                                author  price price (including used books)  \
# 0                 [ Dr Dhaval Maheta]   6.75                         6.75
# 1                                 NaN  33.72               21.49 - 33.72
# 2  [ Oz du Soleil,  and , Bill Jelen]  32.07                        32.07
# 3                 [ William McKinney]  53.99                        53.99
# 4                   [ Paul McFedries]  24.49                        24.49
#
#   pages  avg_reviews n_reviews star5 star4 star3 star2 star1  \
# 0   500          4.4        23   55%   39%    6%   NaN   NaN
# 1   484          4.3       124   61%   20%    9%    4%    6%
# ...

# %%
d.tail()
# Out:
#                                                  title  \
# 825   Deep Learning: Engage the World Change the World
# 826  Machine Learning in Finance: From Theory to Pr...
# 827  Practical Deep Learning at Scale with MLflow: ...
# 828  Clinical Biostatistics and Epidemiology Made R...
# 829  AI and Machine Learning for Coders: A Programm...
#
#                                          author  price  \
# 825     [ Michael Fullan, Joanne Quinn, et al.]   5.33
# 826  [ Matthew F. Dixon, Igor Halperin, et al.]  55.18
# 827       [ Yong Liu,  and , Dr. Matei Zaharia]  44.99
# 828                                         NaN    NaN
# 829                         [ Laurence Moroney]  38.49
#
#     price (including used books) pages  avg_reviews n_reviews star5 star4  \
# 825                8.55 - 35.33    208          4.5        74   72%   14%
# 826               52.41 - 55.18    573          4.5        93   78%    7%
# ...

# %%
d.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-19b5875a9707> in <cell line: 0>()
# ----> 1 d.shape()
#
# TypeError: 'tuple' object is not callable

# %%
d.shape
# Out:
# (830, 19)

# %%
d.columns
# Out:
# Index(['title', 'author', 'price', 'price (including used books)', 'pages',
#        'avg_reviews', 'n_reviews', 'star5', 'star4', 'star3', 'star2', 'star1',
#        'dimensions', 'weight', 'language', 'publisher', 'ISBN_13', 'link',
#        'complete_link'],
#       dtype='object')

# %%
d.iloc[5]
# Out:
# title                           Everything Data Analytics: A Beginner's Guide ...
# author                                                                        NaN
# price                                                                         NaN
# price (including used books)                                                  NaN
# pages                                                                         NaN
# avg_reviews                                                                   4.2
# n_reviews                                                                      31
# star5                                                                         61%
# star4                                                                         16%
# star3                                                                         14%
# star2                                                                          4%
# ...

# %%
d.dtypes
# Out:
# title                            object
# author                           object
# price                           float64
# price (including used books)     object
# pages                            object
# avg_reviews                     float64
# n_reviews                        object
# star5                            object
# star4                            object
# star3                            object
# star2                            object
# star1                            object
# dimensions                       object
# weight                           object
# language                         object
# publisher                        object
# ISBN_13                          object
# link                             object
# complete_link                    object
# dtype: object

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         830 non-null    object
#  1   author                        657 non-null    object
#  2   price                         722 non-null    float64
#  3   price (including used books)  722 non-null    object
#  4   pages                         745 non-null    object
#  5   avg_reviews                   702 non-null    float64
#  6   n_reviews                     702 non-null    object
#  7   star5                         702 non-null    object
#  8   star4                         635 non-null    object
#  9   star3                         554 non-null    object
#  10  star2                         451 non-null    object
#  11  star1                         328 non-null    object
# ...

# %%
d.describe()
# Out:
#              price  avg_reviews
# count   722.000000   702.000000
# mean     46.491537     4.472080
# std      63.292394     0.409608
# min       0.990000     1.000000
# 25%      23.725000     4.325000
# 50%      39.490000     4.500000
# 75%      51.990000     4.700000
# max    1318.740000     5.000000

# %%
Y = d['price'][5]

# %%
print(Y)
# Out:
# nan

# %%
d['price'].iloc[5:10]
# Out:
# 5      NaN
# 6    40.49
# 7    90.00
# 8    54.19
# 9    56.99
# Name: price, dtype: float64

# %%
d[['pages', 'author']].iloc[5]
# Out:
# pages     NaN
# author    NaN
# Name: 5, dtype: object

# %%
d['new_col'] = d['price'] + d['height']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-33914b00ac6d> in <cell line: 0>()
# ----> 1 d['new_col'] = d['price'] + d['height']
#
# ...

# %%
d.columns
# Out:
# Index(['title', 'author', 'price', 'price (including used books)', 'pages',
#        'avg_reviews', 'n_reviews', 'star5', 'star4', 'star3', 'star2', 'star1',
#        'dimensions', 'weight', 'language', 'publisher', 'ISBN_13', 'link',
#        'complete_link'],
#       dtype='object')

# %%
d['new_col'] = d['price'] + d['pages']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# ...

# %%
d.columns
# Out:
# Index(['title', 'author', 'price', 'price (including used books)', 'pages',
#        'avg_reviews', 'n_reviews', 'star5', 'star4', 'star3', 'star2', 'star1',
#        'dimensions', 'weight', 'language', 'publisher', 'ISBN_13', 'link',
#        'complete_link'],
#       dtype='object')

# %%
d['a'] = 5

# %%
d[d['dimensions'] < 0.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-d7b8373d3365> in <cell line: 0>()
# ----> 1 d[d['dimensions'] < 0.5]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6117         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6118
# ...

# %%
import pandas as p

# %%
d = p.read_csv('sample_data/random_data.csv')

# %%
d = p.read_csv('sample_data/random_data.csv')

# %%
d['new_col'] = d['Feature2'] + 5

# %%
d[['Feature2']]
# Out:
#       Feature2
# 0     0.797417
# 1     0.026838
# 2     0.199990
# 3     0.474124
# 4     0.598516
# ...        ...
# 4995  0.819440
# 4996  0.032140
# 4997  0.263300
# 4998  0.640986
# 4999  0.901570
#
# [5000 rows x 1 columns]

# %%
d[d['Feature2'] < 0.5]
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 11         NaN  0.087169 -0.293628        A       0.0     587.0  2.428588
# 12        88.0  0.329888  0.245180      NaN       NaN       NaN  0.814215
# ...        ...       ...       ...      ...       ...       ...       ...
# 4987       4.0  0.011676  1.152884        A       0.0     127.0  0.088079
# 4992      42.0  0.271165  0.021821        C       NaN       NaN  0.947761
# 4993      84.0  0.091607 -1.366911        D       NaN     705.0  1.673878
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
#
#       Feature8  Feature9  Feature10  ...  Feature12 Feature13  Feature14  \
# ...

# %%
a = d[d['Feature2'] < 0.5]

# %%
a
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 11         NaN  0.087169 -0.293628        A       0.0     587.0  2.428588
# 12        88.0  0.329888  0.245180      NaN       NaN       NaN  0.814215
# ...        ...       ...       ...      ...       ...       ...       ...
# 4987       4.0  0.011676  1.152884        A       0.0     127.0  0.088079
# 4992      42.0  0.271165  0.021821        C       NaN       NaN  0.947761
# 4993      84.0  0.091607 -1.366911        D       NaN     705.0  1.673878
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
#
#       Feature8  Feature9  Feature10  ...  Feature12 Feature13  Feature14  \
# ...

# %%
d[(d['Feature2'] < 0.5) & (d['Feature3'] > 0)]
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5    Feature6  Feature7  \
# 3         67.0  0.474124  0.448040        B       NaN  166.000000  0.635091
# 12        88.0  0.329888  0.245180      NaN       NaN         NaN  0.814215
# 16         NaN  0.196474  0.983773      NaN       NaN  734.000000  0.483883
# 21         NaN  0.397841  0.248413      NaN       NaN  375.494983  0.881802
# 33         NaN  0.221392  0.475404      NaN       0.0         NaN  0.110751
# ...        ...       ...       ...      ...       ...         ...       ...
# 4983       NaN  0.245673  1.273752        B       0.0  133.000000  1.245834
# 4985       NaN  0.418488  0.231568        C       NaN         NaN  2.615529
# 4987       4.0  0.011676  1.152884        A       0.0  127.000000  0.088079
# 4992      42.0  0.271165  0.021821        C       NaN         NaN  0.947761
# 4997      92.0  0.263300  0.986722        C       NaN   78.000000  1.326853
#
# ...

# %%
d[d['Feature2'] > d['Feature3']]
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4          NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4993      84.0  0.091607 -1.366911        D       NaN     705.0  1.673878
# 4994       NaN  0.635389 -1.115966      NaN       NaN       NaN  0.050992
# 4995       NaN  0.819440  0.415931        C       0.0       NaN  1.765590
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
#
#       Feature8  Feature9  Feature10  ...  Feature12 Feature13  Feature14  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Feature1   2296 non-null   float64
#  1   Feature2   5000 non-null   float64
#  2   Feature3   5000 non-null   float64
#  3   Feature4   3132 non-null   object
#  4   Feature5   2968 non-null   float64
#  5   Feature6   3016 non-null   float64
#  6   Feature7   5000 non-null   float64
#  7   Feature8   4899 non-null   float64
#  8   Feature9   5000 non-null   float64
#  9   Feature10  2164 non-null   float64
#  10  Feature11  5000 non-null   int64
#  11  Feature12  5000 non-null   object
#  12  Feature13  5000 non-null   int64
#  13  Feature14  5000 non-null   object
#  14  Feature15  5000 non-null   object
#  15  Feature16  2994 non-null   float64
#  16  Feature17  5000 non-null   float64
#  17  Feature18  5000 non-null   object
#  18  Feature19  4705 non-null   object
# ...

# %%
d.select_dtypes(include=['object'])
# Out:
#      Feature4 Feature12  Feature14 Feature15 Feature18 Feature19   Feature20
# 0         NaN         X  Category1   Option4       Yes       Low         NaN
# 1           D         X  Category1   Option2       Yes       Low         cat
# 2           B         Z  Category1   Option2       Yes    Medium         dog
# 3           B         X  Category1   Option2       Yes       Low         cat
# 4         NaN         Z  Category1   Option3       Yes       Low         cat
# ...       ...       ...        ...       ...       ...       ...         ...
# 4995        C         Z  Category2   Option4        No       Low         NaN
# 4996        C         Y  Category3   Option4       Yes    Medium         NaN
# 4997        C         X  Category1   Option4       Yes    Medium         NaN
# 4998        A         X  Category1   Option3        No    Medium  some other
# 4999      NaN         X  Category2   Option2       Yes      High  some other
#
# [5000 rows x 7 columns]

# %%
d.isnull().sum()
# Out:
# Feature1     2704
# Feature2        0
# Feature3        0
# Feature4     1868
# Feature5     2032
# Feature6     1984
# Feature7        0
# Feature8      101
# Feature9        0
# Feature10    2836
# Feature11       0
# Feature12       0
# Feature13       0
# Feature14       0
# Feature15       0
# Feature16    2006
# Feature17       0
# Feature18       0
# Feature19     295
# Feature20    1733
# new_col         0
# dtype: int64

# %%
d.notnull().sum()
# Out:
# Feature1     2296
# Feature2     5000
# Feature3     5000
# Feature4     3132
# Feature5     2968
# Feature6     3016
# Feature7     5000
# Feature8     4899
# Feature9     5000
# Feature10    2164
# Feature11    5000
# Feature12    5000
# Feature13    5000
# Feature14    5000
# Feature15    5000
# Feature16    2994
# Feature17    5000
# Feature18    5000
# Feature19    4705
# Feature20    3267
# new_col      5000
# dtype: int64

# %%
d.dropna()
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 171       95.0  0.703015  0.588349        A       0.0     202.0  4.277223
# 209       54.0  0.933366 -1.032108        D       0.0     203.0  1.213096
# 232       10.0  0.340107 -0.188947        C       0.0     715.0  4.862813
# 343       51.0  0.724042  0.326311        B       1.0     110.0  1.784348
# 531       71.0  0.067583 -2.938568        B       0.0     545.0  1.358502
# ...        ...       ...       ...      ...       ...       ...       ...
# 4800       0.0  0.849989  0.302729        C       1.0     171.0  0.113641
# 4814      41.0  0.458115  0.958438        C       0.0     113.0  5.252798
# 4957      29.0  0.790611 -1.156629        D       0.0      83.0  2.282176
# 4962      56.0  0.271911 -0.517786        B       0.0      51.0  0.022858
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
#
#       Feature8  Feature9  Feature10  ...  Feature12 Feature13  Feature14  \
# ...

# %%
d.fillna(0)
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091        0       0.0     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       0.0       0.0  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       0.0     166.0  0.635091
# 4          0.0  0.598516  0.087839        0       0.0       0.0  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4995       0.0  0.819440  0.415931        C       0.0       0.0  1.765590
# 4996       0.0  0.032140 -1.445420        C       1.0       0.0  0.806246
# 4997      92.0  0.263300  0.986722        C       0.0      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       0.0  0.901570  1.836382        0       0.0       0.0  2.087461
#
#       Feature8  Feature9  Feature10  ...  Feature12 Feature13  Feature14  \
# ...

# %%
d['Feature4'].replace({'D':'C','B':'A'})
# Out:
# 0       NaN
# 1         C
# 2         A
# 3         A
# 4       NaN
#        ...
# 4995      C
# 4996      C
# 4997      C
# 4998      A
# 4999    NaN
# Name: Feature4, Length: 5000, dtype: object
